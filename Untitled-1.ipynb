# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('LMR_VOCdata_97-19_DOW.csv')

df['Datetime'] = pd.to_datetime(df['Datetime'], format='%Y-%m-%d %H:%M:%S',errors='coerce')

# %%
# code to select data from within a time period
# dates to be in the form: '%Y-%m-%d %H:%M:%S'
def select_data(start_date,end_date):
    mask = (df['Datetime'] > start_date) & (df['Datetime'] < end_date)
    data = df.loc[mask]
    return data

# %%
# ethane and propane ratio looks weird between this period so investigating this futher
ethane_propane = select_data('2012/1/1','2017')
ethane_propane['ratio'] = ethane_propane['ethane'] / ethane_propane['propane']
# Out:
# <ipython-input-30-1379b1a6dcd0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ethane_propane['ratio'] = ethane_propane['ethane'] / ethane_propane['propane']

# %%
sns.lineplot(data=ethane_propane,x='Datetime',y='ethane')

# %%
sns.lineplot(data=ethane_propane,x='Datetime',y='propane')

# %%
sns.lineplot(data=ethane_propane,x='Datetime',y='ratio')

# %%
# there was a storm on the 26th may 2018 (lots of lightning) 
stormy2018 = select_data('2018/05','2018/06')
stormy2018['ratio'] = stormy2018['Nitric oxide'] / stormy2018['Nitrogen dioxide']
plt.plot(stormy2018['Datetime'],stormy2018['Nitric oxide'],color='r',label='Nitric oxide')
plt.plot(stormy2018['Datetime'],stormy2018['Nitrogen dioxide'],color='b',label='Nitrogen dioxide')
plt.plot(stormy2018['Datetime'],stormy2018['ratio'],color='g',label='ratio')
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-51-1db476076628>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stormy2018['ratio'] = stormy2018['Nitric oxide'] / stormy2018['Nitrogen dioxide']

# %%
# another thunder storm 18th july 2014 but weirdly looks like more was going on at the begining of the month
stormy2014 = select_data('2014/07','2014/08')
stormy2014['ratio'] = stormy2014['Nitric oxide'] / stormy2014['Nitrogen dioxide']
plt.plot(stormy2014['Datetime'],stormy2014['Nitric oxide'],color='r',label='Nitric oxide')
plt.plot(stormy2014['Datetime'],stormy2014['Nitrogen dioxide'],color='b',label='Nitrogen dioxide')
plt.plot(stormy2014['Datetime'],stormy2014['ratio'],color='g',label='ratio')
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-52-fa599d5d3478>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stormy2014['ratio'] = stormy2014['Nitric oxide'] / stormy2014['Nitrogen dioxide']

# %%
corr['benzene'].sort_values(ascending =False)
# Out:
# Ozone                            -0.246534
# propane                           0.196506
# ethane                            0.232973
# Nitrogen dioxide                  0.248350
# Nitric oxide                      0.478274
# Sulphur dioxide                   0.566531
# cis-2-pentene (VOC-AIR only)      0.586694
# 1,2,4-trimethylbenzene            0.621144
# n-heptane                         0.629502
# ethylbenzene                      0.633329
# trans-2-pentene                   0.649538
# isoprene                          0.726549
# m+p-xylene                        0.726630
# 1,3,5-trimethylbenzene            0.788013
# Carbon monoxide                   0.797709
# ethyne                            0.798176
# o-xylene                          0.805815
# n-hexane                          0.816503
# n-butane                          0.835750
# n-pentane                         0.841624
# cis-2-butene                      0.852467
# 3-methylpentane (VOC-AIR only)    0.853302
# iso-butane                        0.853461
# 1-butene                          0.867878
# trans-2-butene                    0.889540
# 1,3-butadiene                     0.900351
# 2-methylpentane                   0.901065
# iso-pentane                       0.902903
# toluene                           0.917445
# propene                           0.946595
# ethene                            0.948488
# benzene                           1.000000
# Name: benzene, dtype: float64

# %%
corr['ethene'].sort_values(ascending=False)
# Out:
# ethene                            1.000000
# propene                           0.984076
# toluene                           0.952474
# benzene                           0.948488
# 2-methylpentane                   0.917947
# iso-pentane                       0.911426
# 1,3-butadiene                     0.897942
# trans-2-butene                    0.892806
# 1-butene                          0.874175
# iso-butane                        0.870673
# n-pentane                         0.870355
# ethyne                            0.864656
# Carbon monoxide                   0.862189
# 3-methylpentane (VOC-AIR only)    0.851319
# o-xylene                          0.845812
# cis-2-butene                      0.845020
# n-butane                          0.818406
# 1,3,5-trimethylbenzene            0.800867
# n-hexane                          0.791361
# m+p-xylene                        0.765689
# isoprene                          0.688973
# ethylbenzene                      0.657458
# 1,2,4-trimethylbenzene            0.635930
# trans-2-pentene                   0.631524
# Sulphur dioxide                   0.624579
# n-heptane                         0.598009
# Nitric oxide                      0.572764
# cis-2-pentene (VOC-AIR only)      0.556776
# Nitrogen dioxide                  0.315029
# ethane                            0.302598
# propane                           0.255168
# Ozone                            -0.319018
# Name: ethene, dtype: float64

# %%
t = df.T
t['vocs'] = t.index
t.columns = t.iloc[0]
t.drop(index='Datetime', axis=1, inplace=True)
# Out:
# Datetime                       1997-07-17 01:00:00 1997-07-17 02:00:00  \
# Ozone                                            2                 NaN
# Nitric oxide                                    98                 159
# Nitrogen dioxide                                69                  71
# Sulphur dioxide                                 16                 NaN
# Carbon monoxide                                1.9                 NaN
# ethane                                         NaN                 NaN
# ethene                                         NaN                 NaN
# ethyne                                         NaN                 NaN
# propane                                        NaN                 NaN
# propene                                        NaN                 NaN
# iso-butane                                     NaN                 NaN
# n-butane                                       NaN                 NaN
# 1-butene                                       NaN                 NaN
# trans-2-butene                                 NaN                 NaN
# cis-2-butene                                   NaN                 NaN
# iso-pentane                                    NaN                 NaN
# n-pentane                                      NaN                 NaN
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                                NaN                 NaN
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                                NaN                 NaN
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                       NaN                 NaN
# n-heptane                                      NaN                 NaN
# benzene                                        NaN                 NaN
# toluene                                        NaN                 NaN
# ethylbenzene                                   NaN                 NaN
# m+p-xylene                                     NaN                 NaN
# o-xylene                                       NaN                 NaN
# 1,2,4-trimethylbenzene                         NaN                 NaN
# 1,3,5-trimethylbenzene                         NaN                 NaN
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       1997-07-17 03:00:00 1997-07-17 04:00:00  \
# Ozone                                            2                   2
# Nitric oxide                                   NaN                 151
# Nitrogen dioxide                               NaN                  61
# Sulphur dioxide                                 24                  24
# Carbon monoxide                                1.9                 1.6
# ethane                                         NaN                 NaN
# ethene                                         NaN                 NaN
# ethyne                                         NaN                 NaN
# propane                                        NaN                 NaN
# propene                                        NaN                 NaN
# iso-butane                                     NaN                 NaN
# n-butane                                       NaN                 NaN
# 1-butene                                       NaN                 NaN
# trans-2-butene                                 NaN                 NaN
# cis-2-butene                                   NaN                 NaN
# iso-pentane                                    NaN                 NaN
# n-pentane                                      NaN                 NaN
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                                NaN                 NaN
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                                NaN                 NaN
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                       NaN                 NaN
# n-heptane                                      NaN                 NaN
# benzene                                        NaN                 NaN
# toluene                                        NaN                 NaN
# ethylbenzene                                   NaN                 NaN
# m+p-xylene                                     NaN                 NaN
# o-xylene                                       NaN                 NaN
# 1,2,4-trimethylbenzene                         NaN                 NaN
# 1,3,5-trimethylbenzene                         NaN                 NaN
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       1997-07-17 05:00:00 1997-07-17 06:00:00  \
# Ozone                                            4                   4
# Nitric oxide                                   210                 345
# Nitrogen dioxide                                67                  69
# Sulphur dioxide                                 27                  35
# Carbon monoxide                                  2                 2.7
# ethane                                         NaN                 NaN
# ethene                                         NaN                 NaN
# ethyne                                         NaN                 NaN
# propane                                        NaN                 NaN
# propene                                        NaN                 NaN
# iso-butane                                     NaN                 NaN
# n-butane                                       NaN                 NaN
# 1-butene                                       NaN                 NaN
# trans-2-butene                                 NaN                 NaN
# cis-2-butene                                   NaN                 NaN
# iso-pentane                                    NaN                 NaN
# n-pentane                                      NaN                 NaN
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                                NaN                 NaN
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                                NaN                 NaN
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                       NaN                 NaN
# n-heptane                                      NaN                 NaN
# benzene                                        NaN                 NaN
# toluene                                        NaN                 NaN
# ethylbenzene                                   NaN                 NaN
# m+p-xylene                                     NaN                 NaN
# o-xylene                                       NaN                 NaN
# 1,2,4-trimethylbenzene                         NaN                 NaN
# 1,3,5-trimethylbenzene                         NaN                 NaN
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       1997-07-17 07:00:00 1997-07-17 08:00:00  \
# Ozone                                            6                   4
# Nitric oxide                                   439                 428
# Nitrogen dioxide                                90                 124
# Sulphur dioxide                                 40                  37
# Carbon monoxide                                4.2                 5.5
# ethane                                         NaN                 NaN
# ethene                                         NaN                 NaN
# ethyne                                         NaN                 NaN
# propane                                        NaN                 NaN
# propene                                        NaN                 NaN
# iso-butane                                     NaN                 NaN
# n-butane                                       NaN                 NaN
# 1-butene                                       NaN                 NaN
# trans-2-butene                                 NaN                 NaN
# cis-2-butene                                   NaN                 NaN
# iso-pentane                                    NaN                 NaN
# n-pentane                                      NaN                 NaN
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                                NaN                 NaN
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                                NaN                 NaN
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                       NaN                 NaN
# n-heptane                                      NaN                 NaN
# benzene                                        NaN                 NaN
# toluene                                        NaN                 NaN
# ethylbenzene                                   NaN                 NaN
# m+p-xylene                                     NaN                 NaN
# o-xylene                                       NaN                 NaN
# 1,2,4-trimethylbenzene                         NaN                 NaN
# 1,3,5-trimethylbenzene                         NaN                 NaN
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       1997-07-17 09:00:00 1997-07-17 10:00:00  ...  \
# Ozone                                            6                   4  ...
# Nitric oxide                                   506                 464  ...
# Nitrogen dioxide                               113                  90  ...
# Sulphur dioxide                                 37                  37  ...
# Carbon monoxide                                5.9                 5.6  ...
# ethane                                         NaN                 NaN  ...
# ethene                                         NaN                 NaN  ...
# ethyne                                         NaN                 NaN  ...
# propane                                        NaN                 NaN  ...
# propene                                        NaN                 NaN  ...
# iso-butane                                     NaN                 NaN  ...
# n-butane                                       NaN                 NaN  ...
# 1-butene                                       NaN                 NaN  ...
# trans-2-butene                                 NaN                 NaN  ...
# cis-2-butene                                   NaN                 NaN  ...
# iso-pentane                                    NaN                 NaN  ...
# n-pentane                                      NaN                 NaN  ...
# 1,3-butadiene                                  NaN                 NaN  ...
# trans-2-pentene                                NaN                 NaN  ...
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN  ...
# 2-methylpentane                                NaN                 NaN  ...
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN  ...
# isoprene                                       NaN                 NaN  ...
# n-hexane                                       NaN                 NaN  ...
# n-heptane                                      NaN                 NaN  ...
# benzene                                        NaN                 NaN  ...
# toluene                                        NaN                 NaN  ...
# ethylbenzene                                   NaN                 NaN  ...
# m+p-xylene                                     NaN                 NaN  ...
# o-xylene                                       NaN                 NaN  ...
# 1,2,4-trimethylbenzene                         NaN                 NaN  ...
# 1,3,5-trimethylbenzene                         NaN                 NaN  ...
# Wind Direction                                 NaN                 NaN  ...
# Wind Speed                                     NaN                 NaN  ...
#
# Datetime                       2019-12-31 16:00:00 2019-12-31 17:00:00  \
# Ozone                                      1.69635             2.49463
# Nitric oxide                               102.871             76.9091
# Nitrogen dioxide                           57.5045              57.497
# Sulphur dioxide                            5.44833             4.43938
# Carbon monoxide                           0.185066            0.139511
# ethane                                     16.8498             16.9307
# ethene                                     3.67088             3.43833
# ethyne                                      1.2761             1.34704
# propane                                    9.33419             8.41345
# propene                                    1.31522             1.20158
# iso-butane                                 3.56727             2.84056
# n-butane                                   5.93647             4.79741
# 1-butene                                  0.315962            0.282154
# trans-2-butene                            0.210264            0.165797
# cis-2-butene                              0.050277                 NaN
# iso-pentane                                2.75944             2.07566
# n-pentane                                  1.25481             1.01073
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                           0.108311            0.064163
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                           0.647961            0.458106
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                  0.539931            0.462989
# n-heptane                                 0.338103            0.268744
# benzene                                    1.16369            0.964999
# toluene                                    2.21166               1.906
# ethylbenzene                              0.387489            0.343148
# m+p-xylene                                 1.20443            0.920869
# o-xylene                                  0.456564            0.551858
# 1,2,4-trimethylbenzene                    0.417529            0.368659
# 1,3,5-trimethylbenzene                    0.145258            0.142768
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       2019-12-31 18:00:00 2019-12-31 19:00:00  \
# Ozone                                      2.89377             4.88946
# Nitric oxide                               79.4955              56.169
# Nitrogen dioxide                           60.2783             56.7492
# Sulphur dioxide                            4.64117             3.69948
# Carbon monoxide                           0.130969            0.162288
# ethane                                     17.3632             19.2466
# ethene                                     4.00033             4.70337
# ethyne                                     1.14254             1.28809
# propane                                    8.59354             9.24811
# propene                                     1.5636             1.54975
# iso-butane                                 2.87382             3.30471
# n-butane                                   4.83608             5.45453
# 1-butene                                  0.348703             0.29555
# trans-2-butene                            0.136175            0.147592
# cis-2-butene                              0.060356              0.0637
# iso-pentane                                2.06155             2.25079
# n-pentane                                  1.03783             1.12077
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                           0.068919            0.082151
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                           0.417558            0.437472
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                  0.527347                 NaN
# n-hexane                                  0.472686            0.499965
# n-heptane                                 0.333671            0.295698
# benzene                                   0.891511             1.02944
# toluene                                    1.87935             1.90344
# ethylbenzene                              0.314873            0.297603
# m+p-xylene                                 1.03491            0.993913
# o-xylene                                   0.47724            0.491486
# 1,2,4-trimethylbenzene                    0.243148            0.415192
# 1,3,5-trimethylbenzene                    0.117454            0.104077
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       2019-12-31 20:00:00 2019-12-31 21:00:00  \
# Ozone                                      8.93076             11.1759
# Nitric oxide                               42.6025             49.9226
# Nitrogen dioxide                           44.0381             44.7513
# Sulphur dioxide                            3.02685             3.22864
# Carbon monoxide                           0.133817            0.165135
# ethane                                     12.6758             13.3164
# ethene                                     3.01318              3.4361
# ethyne                                     1.35491               1.277
# propane                                     7.0523             7.29617
# propene                                    1.13172             1.01161
# iso-butane                                 2.50741              2.6822
# n-butane                                   3.98312               4.391
# 1-butene                                  0.197134            0.209469
# trans-2-butene                            0.080739            0.095467
# cis-2-butene                               0.05108            0.047677
# iso-pentane                                1.46516             1.29292
# n-pentane                                 0.778016            0.675358
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                           0.085615            0.045595
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                           0.264504            0.234891
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                  0.315114            0.255434
# n-heptane                                 0.142937            0.142189
# benzene                                   0.756774            0.776985
# toluene                                     1.2642             1.09565
# ethylbenzene                              0.199297            0.203778
# m+p-xylene                                0.532764            0.550232
# o-xylene                                  0.206197            0.226535
# 1,2,4-trimethylbenzene                     0.12066            0.192046
# 1,3,5-trimethylbenzene                    0.079622            0.075737
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       2019-12-31 22:00:00 2019-12-31 23:00:00  \
# Ozone                                      10.8766             6.53592
# Nitric oxide                               39.9185             48.2634
# Nitrogen dioxide                           40.9616              42.476
# Sulphur dioxide                            3.02685             3.49769
# Carbon monoxide                           0.159441            0.216384
# ethane                                        10.3             12.8613
# ethene                                     3.13903             3.88612
# ethyne                                     1.06533             1.15644
# propane                                    6.03601             7.16088
# propene                                    1.03715             1.20666
# iso-butane                                  2.4552             2.62559
# n-butane                                   4.00318              3.9158
# 1-butene                                  0.212336            0.206444
# trans-2-butene                            0.086973            0.092951
# cis-2-butene                              0.035784            0.121943
# iso-pentane                                1.27418             1.15468
# n-pentane                                 0.656064            0.655741
# 1,3-butadiene                                  NaN                 NaN
# trans-2-pentene                           0.049321            0.033656
# cis-2-pentene (VOC-AIR only)                   NaN                 NaN
# 2-methylpentane                           0.203284            0.187309
# 3-methylpentane (VOC-AIR only)                 NaN                 NaN
# isoprene                                       NaN                 NaN
# n-hexane                                   0.33183            0.222833
# n-heptane                                 0.152701            0.150779
# benzene                                   0.749081            0.799948
# toluene                                   0.926911            0.992097
# ethylbenzene                              0.113459            0.113489
# m+p-xylene                                0.434309            0.352204
# o-xylene                                  0.190926             0.20714
# 1,2,4-trimethylbenzene                    0.156088             0.15845
# 1,3,5-trimethylbenzene                    0.077177                 NaN
# Wind Direction                                 NaN                 NaN
# Wind Speed                                     NaN                 NaN
#
# Datetime                       2020-01-01 00:00:00  \
# Ozone                                      2.24516
# Nitric oxide                               51.8746
# Nitrogen dioxide                           53.3246
# Sulphur dioxide                            3.69948
# Carbon monoxide                           0.355895
# ethane                                     11.5429
# ethene                                      3.5826
# ethyne                                     1.49864
# propane                                    7.28866
# propene                                    1.58077
# iso-butane                                 2.56431
# n-butane                                   4.15621
# 1-butene                                  0.268024
# trans-2-butene                            0.098817
# cis-2-butene                              0.065479
# iso-pentane                                1.26682
# n-pentane                                 0.789398
# 1,3-butadiene                                  NaN
# trans-2-pentene                                NaN
# cis-2-pentene (VOC-AIR only)                   NaN
# 2-methylpentane                           0.264088
# 3-methylpentane (VOC-AIR only)                 NaN
# isoprene                                       NaN
# n-hexane                                  0.351071
# n-heptane                                 0.160987
# benzene                                    1.19657
# toluene                                    1.43751
# ethylbenzene                              0.368033
# m+p-xylene                                0.983539
# o-xylene                                  0.328004
# 1,2,4-trimethylbenzene                    0.245207
# 1,3,5-trimethylbenzene                         NaN
# Wind Direction                                 NaN
# Wind Speed                                     NaN
#
# Datetime                                              Datetime
# Ozone                                                    Ozone
# Nitric oxide                                      Nitric oxide
# Nitrogen dioxide                              Nitrogen dioxide
# Sulphur dioxide                                Sulphur dioxide
# Carbon monoxide                                Carbon monoxide
# ethane                                                  ethane
# ethene                                                  ethene
# ethyne                                                  ethyne
# propane                                                propane
# propene                                                propene
# iso-butane                                          iso-butane
# n-butane                                              n-butane
# 1-butene                                              1-butene
# trans-2-butene                                  trans-2-butene
# cis-2-butene                                      cis-2-butene
# iso-pentane                                        iso-pentane
# n-pentane                                            n-pentane
# 1,3-butadiene                                    1,3-butadiene
# trans-2-pentene                                trans-2-pentene
# cis-2-pentene (VOC-AIR only)      cis-2-pentene (VOC-AIR only)
# 2-methylpentane                                2-methylpentane
# 3-methylpentane (VOC-AIR only)  3-methylpentane (VOC-AIR only)
# isoprene                                              isoprene
# n-hexane                                              n-hexane
# n-heptane                                            n-heptane
# benzene                                                benzene
# toluene                                                toluene
# ethylbenzene                                      ethylbenzene
# m+p-xylene                                          m+p-xylene
# o-xylene                                              o-xylene
# 1,2,4-trimethylbenzene                  1,2,4-trimethylbenzene
# 1,3,5-trimethylbenzene                  1,3,5-trimethylbenzene
# Wind Direction                                  Wind Direction
# Wind Speed                                          Wind Speed
#
# [34 rows x 196873 columns]

# %%
g = sns.lmplot('final_sec', 'split_frac', col='gender', data=data,
               markers=".", scatter_kws=dict(color='c'))
g.map(plt.axhline, y=0.1, color="k", ls=":");

# %%
sns.lineplot(data=df, x='Datetime',y='benzene')

# %%
with sns.axes_style('white'):
    sns.jointplot("benzene", "toluene", df, kind='kde');

# %%
df['']

# %%
from pyrqa.time_series import TimeSeries
from pyrqa.settings import Settings
from pyrqa.analysis_type import Classic
from pyrqa.neighbourhood import FixedRadius
from pyrqa.metric import EuclideanMetric
from pyrqa.computation import RQAComputation
from pyrqa.computation import RPComputation
from pyrqa.image_generator import ImageGenerator
from DataSelect import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
data_points = vocData().select(groupby='M')
data_points = data_points['benzene']
time_series = TimeSeries(data_points,
                         embedding_dimension=2,
                         time_delay=2)
settings = Settings(time_series,
                    analysis_type=Classic,
                    neighbourhood=FixedRadius(0.65),
                    similarity_measure=EuclideanMetric,
                    theiler_corrector=1)
computation = RQAComputation.create(settings,
                                    verbose=True)
result = computation.run()
result.min_diagonal_line_length = 2
result.min_vertical_line_length = 2
result.min_white_vertical_line_length = 2

# %%
result.recurrence_rate

# %%
computation = RPComputation.create(settings)
result = computation.run()
ImageGenerator.save_recurrence_plot(result.recurrence_matrix_reverse,
                                    'recurrence_plot.png')
img=mpimg.imread('recurrence_plot.png')
imgplot = plt.imshow(img)
plt.show()

# %%
df = vocData()
day = df.select(groupby='D')
month = df.select(groupby='M')
year = df.select(groupby='Y')
day = day[['benzene','toluene']]
month = month[['benzene','toluene']]
year = year[['benzene','toluene']]

# %%
data_points = day['benzene']

# %%
df = vocData().select('1997')
df

# %%
import json 
data = {'benzene':{'D':{},'M':{},'Y':{}},'toluene':{'D':{},'M':{},'Y':{}}}

with open("rqa_test.json", "w") as outfile:
    json.dump(data, outfile)

# %%
with open('rqa_all/rqa.json') as json_file:
    data = json.load(json_file)

# %%
data

# %%
pd.DataFrame.from_dict(data, orient='columns')

# %%
with open('rqa_all/rqa.json') as json_file:
    data = json.load(json_file)
pd.DataFrame.from_dict(data, orient='columns')
pd.DataFrame.from_dict({(i,j): data[i][j] 
                           for i in data.keys() 
                           for j in data[i].keys()},
                       orient='index').T

# %%
with open('rqa_2010-2019/rqa_2010-2019.json') as json_file:
    data = json.load(json_file)
pd.DataFrame.from_dict(data, orient='columns')
pd.DataFrame.from_dict({(i,j): data[i][j] 
                           for i in data.keys() 
                           for j in data[i].keys()},
                       orient='index').T

# %%
with open('rqa_1997-2009/rqa_1997-2009.json') as json_file:
    data = json.load(json_file)
pd.DataFrame.from_dict(data, orient='columns')
pd.DataFrame.from_dict({(i,j): data[i][j] 
                           for i in data.keys() 
                           for j in data[i].keys()},
                       orient='index').T

# %%
from pyrqa.analysis_type import Cross
data_points_x = month['benzene']
data_points_y = month['toluene']
time_series_x = TimeSeries(data_points_x,
                           embedding_dimension=2,
                           time_delay=1)
time_series_y = TimeSeries(data_points_y,
                           embedding_dimension=2,
                           time_delay=2)
time_series = (time_series_x,
               time_series_y)
settings = Settings(time_series,
                    analysis_type=Cross,
                    neighbourhood=FixedRadius(0.73),
                    similarity_measure=EuclideanMetric,
                    theiler_corrector=0)
computation = RQAComputation.create(settings,
                                    verbose=True)
result = computation.run()
result.min_diagonal_line_length = 2
result.min_vertical_line_length = 2
result.min_white_vertical_line_length = 2
print(result)

# %%
from pyrqa.computation import RPComputation
from pyrqa.image_generator import ImageGenerator
computation = RPComputation.create(settings)
result = computation.run()
ImageGenerator.save_recurrence_plot(result.recurrence_matrix_reverse,
                                    'cross_recurrence_plot.png')

# %%
from pyrqa.computation import JRQAComputation
from pyrqa.metric import MaximumMetric, TaxicabMetric
from pyrqa.settings import JointSettings
from pyrqa.neighbourhood import FixedRadius, RadiusCorridor

time_series_1 = TimeSeries(data_points_x,
                           embedding_dimension=2,
                           time_delay=1)
settings_1 = Settings(time_series_1,
                      analysis_type=Classic,
                      neighbourhood=RadiusCorridor(inner_radius=0.14,
                                                   outer_radius=0.97),
                      similarity_measure=MaximumMetric,
                      theiler_corrector=1)
time_series_2 = TimeSeries(data_points_y,
                             embedding_dimension=2,
                             time_delay=1)

settings_2 = Settings(time_series_2,
                      analysis_type=Classic,
                      neighbourhood=RadiusCorridor(inner_radius=0.14,
                                                   outer_radius=0.97),
                      similarity_measure=MaximumMetric,
                      theiler_corrector=1)
joint_settings = JointSettings(settings_1,
                               settings_2)
computation = JRQAComputation.create(joint_settings,
                                     verbose=True)
result = computation.run()
result.min_diagonal_line_length = 2
result.min_vertical_line_length = 1
result.min_white_vertical_line_length = 2
print(result)

# %%
from pyrqa.computation import JRPComputation
computation = JRPComputation.create(joint_settings)
result = computation.run()
ImageGenerator.save_recurrence_plot(result.recurrence_matrix_reverse,
                                    'joint_recurrence_plot.png')

# %%
data = vocData().select()

# %%
result.recurrence_matrix_reverse

# %%
v = ['benzene','toluene']
a = day[v[0]]
print(a)

# %%
result

# %%
print(result.ratio_laminarity_determinism)

# %%
data_points.index

# %%
img=mpimg.imread('recurrence_plot.png')
imgplot = plt.imshow(img)
plt.xticks([]),plt.yticks([])
plt.show()

# %%
import pandas as pd
ti = pd.date_range(data_points.index[0],data_points.index[-1],periods=8)
ti

# %%
data_points[-1]

# %%
slice = 10
slice_point = int(data_points.shape[0]/slice)
for i in range(slice):
    df = data_points.index.loc[i*slice_point]

# %%
from RQA import *
recs = [['benzene','D','recurrence','data'],
        ['benzene','M','recurrence','data'],
        ['benzene','Y','recurrence','data'],
        ['toluene','D','recurrence','data'],
        ['toluene','M','recurrence','data'],
        ['toluene','Y','recurrence','data'],
        [['benzene','toluene'],'D','joint','data'],
        [['benzene','toluene'],'M','joint','data'],
        [['benzene','toluene'],'Y','joint','data'],
        [['benzene','toluene'],'D','cross','data'],
        [['benzene','toluene'],'M','cross','data'],
        [['benzene','toluene'],'Y','cross','data'],
        ['benzene','D','recurrence','data',['1997','2009']],
        ['benzene','M','recurrence','data',['1997','2009']],
        ['benzene','Y','recurrence','data',['1997','2009']],
        ['toluene','D','recurrence','data',['1997','2009']],
        ['toluene','M','recurrence','data',['1997','2009']],
        ['toluene','Y','recurrence','data',['1997','2009']],
        [['benzene','toluene'],'D','joint','data',['1997','2009']],
        [['benzene','toluene'],'M','joint','data',['1997','2009']],
        [['benzene','toluene'],'Y','joint','data',['1997','2009']],
        [['benzene','toluene'],'D','cross','data',['1997','2009']],
        [['benzene','toluene'],'M','cross','data',['1997','2009']],
        [['benzene','toluene'],'Y','cross','data',['1997','2009']],
        ['benzene','D','recurrence','data',['2010','2020']],
        ['benzene','M','recurrence','data',['2010','2020']],
        ['benzene','Y','recurrence','data',['2010','2020']],
        ['toluene','D','recurrence','data',['2010','2020']],
        ['toluene','M','recurrence','data',['2010','2020']],
        ['toluene','Y','recurrence','data',['2010','2020']],
        [['benzene','toluene'],'D','joint','data',['2010','2020']],
        [['benzene','toluene'],'M','joint','data',['2010','2020']],
        [['benzene','toluene'],'Y','joint','data',['2010','2020']],
        [['benzene','toluene'],'D','cross','data',['2010','2020']],
        [['benzene','toluene'],'M','cross','data',['2010','2020']],
        [['benzene','toluene'],'Y','cross','data',['2010','2020']]

]

df = pd.DataFrame()
for r in recs:
    name, data = rqa(*r)
    d = data.T
    d.columns=[name]
    df = pd.concat([df,d],axis=1)
# Out:
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority

# %%
df
# Out:
#                                                     benzene_D_recurrence  \
# Recurrence rate                                                 0.092562
# Determinism                                                     0.609541
# Average diagonal line length (L)                                3.955820
# Longest diagonal line length (L_max)                           66.000000
# Divergence (DIV)                                                0.015152
# Entropy diagonal lines (L_entr)                                 1.880536
# Laminarity (LAM)                                                0.755076
# Trapping time (TT)                                              4.299439
# Longest vertical line length (V_max)                           93.000000
# Entropy vertical lines (V_entr)                                 1.936408
# Average white vertical line length (W)                         34.624574
# Longest white vertical line length (W_max)                   8202.000000
# Longest white vertical line length inverse (W_div)              0.000122
# Entropy white vertical lines (W_entr)                           3.416791
# Ratio determinism / recurrence rate (DET/RR)                    6.585224
# Ratio laminarity / determinism (LAM/DET)                        1.238763
#
#                                                     benzene_M_recurrence  \
# Recurrence rate                                                 0.198477
# Determinism                                                     0.783416
# Average diagonal line length (L)                                5.127087
# Longest diagonal line length (L_max)                           43.000000
# Divergence (DIV)                                                0.023256
# Entropy diagonal lines (L_entr)                                 2.228021
# Laminarity (LAM)                                                0.883094
# Trapping time (TT)                                              6.165775
# Longest vertical line length (V_max)                           46.000000
# Entropy vertical lines (V_entr)                                 2.392851
# Average white vertical line length (W)                         24.982713
# Longest white vertical line length (W_max)                    269.000000
# Longest white vertical line length inverse (W_div)              0.003717
# Entropy white vertical lines (W_entr)                           3.027993
# Ratio determinism / recurrence rate (DET/RR)                    3.947136
# Ratio laminarity / determinism (LAM/DET)                        1.127235
#
#                                                     benzene_Y_recurrence  \
# Recurrence rate                                                 0.342975
# Determinism                                                     0.986111
# Average diagonal line length (L)                                7.100000
# Longest diagonal line length (L_max)                           13.000000
# Divergence (DIV)                                                0.076923
# Entropy diagonal lines (L_entr)                                 2.163956
# Laminarity (LAM)                                                0.951807
# Trapping time (TT)                                             10.533333
# Longest vertical line length (V_max)                           13.000000
# Entropy vertical lines (V_entr)                                 1.171060
# Average white vertical line length (W)                         10.533333
# Longest white vertical line length (W_max)                     21.000000
# Longest white vertical line length inverse (W_div)              0.047619
# Entropy white vertical lines (W_entr)                           2.586493
# Ratio determinism / recurrence rate (DET/RR)                    2.875167
# Ratio laminarity / determinism (LAM/DET)                        0.965213
#
#                                                     toluene_D_recurrence  \
# Recurrence rate                                                 0.008926
# Determinism                                                     0.128748
# Average diagonal line length (L)                                2.369133
# Longest diagonal line length (L_max)                            9.000000
# Divergence (DIV)                                                0.111111
# Entropy diagonal lines (L_entr)                                 0.797548
# Laminarity (LAM)                                                0.228564
# Trapping time (TT)                                              2.237375
# Longest vertical line length (V_max)                           11.000000
# Entropy vertical lines (V_entr)                                 0.575817
# Average white vertical line length (W)                        134.341941
# Longest white vertical line length (W_max)                   8202.000000
# Longest white vertical line length inverse (W_div)              0.000122
# Entropy white vertical lines (W_entr)                           4.840952
# Ratio determinism / recurrence rate (DET/RR)                   14.423260
# Ratio laminarity / determinism (LAM/DET)                        1.775272
#
#                                                     toluene_M_recurrence  \
# Recurrence rate                                                 0.028897
# Determinism                                                     0.345692
# Average diagonal line length (L)                                2.577236
# Longest diagonal line length (L_max)                            6.000000
# Divergence (DIV)                                                0.166667
# Entropy diagonal lines (L_entr)                                 1.000573
# Laminarity (LAM)                                                0.501674
# Trapping time (TT)                                              2.812332
# Longest vertical line length (V_max)                            8.000000
# Entropy vertical lines (V_entr)                                 1.183833
# Average white vertical line length (W)                         50.957028
# Longest white vertical line length (W_max)                    269.000000
# Longest white vertical line length inverse (W_div)              0.003717
# Entropy white vertical lines (W_entr)                           4.198503
# Ratio determinism / recurrence rate (DET/RR)                   11.963010
# Ratio laminarity / determinism (LAM/DET)                        1.451214
#
#                                                     toluene_Y_recurrence  \
# Recurrence rate                                                 0.074380
# Determinism                                                     0.571429
# Average diagonal line length (L)                                4.000000
# Longest diagonal line length (L_max)                            4.000000
# Divergence (DIV)                                                0.250000
# Entropy diagonal lines (L_entr)                                 0.000000
# Laminarity (LAM)                                                0.527778
# Trapping time (TT)                                              2.714286
# Longest vertical line length (V_max)                            4.000000
# Entropy vertical lines (V_entr)                                 1.004242
# Average white vertical line length (W)                         11.100000
# Longest white vertical line length (W_max)                     21.000000
# Longest white vertical line length inverse (W_div)              0.047619
# Entropy white vertical lines (W_entr)                           2.930327
# Ratio determinism / recurrence rate (DET/RR)                    7.682540
# Ratio laminarity / determinism (LAM/DET)                        0.923611
#
#                                                     benzene_toluene_D_joint  \
# Recurrence rate                                                    0.024579
# Determinism                                                        0.511620
# Average diagonal line length (L)                                   2.492735
# Longest diagonal line length (L_max)                              17.000000
# Divergence (DIV)                                                   0.058824
# Entropy diagonal lines (L_entr)                                    0.945256
# Laminarity (LAM)                                                   0.412994
# Trapping time (TT)                                                 2.535730
# Longest vertical line length (V_max)                              19.000000
# Entropy vertical lines (V_entr)                                    0.983659
# Average white vertical line length (W)                            58.171934
# Longest white vertical line length (W_max)                      8203.000000
# Longest white vertical line length inverse (W_div)                 0.000122
# Entropy white vertical lines (W_entr)                              4.011048
# Ratio determinism / recurrence rate (DET/RR)                      20.815444
# Ratio laminarity / determinism (LAM/DET)                           0.807228
#
#                                                     benzene_toluene_M_joint  \
# Recurrence rate                                                    0.063128
# Determinism                                                        0.781834
# Average diagonal line length (L)                                   3.139616
# Longest diagonal line length (L_max)                              11.000000
# Divergence (DIV)                                                   0.090909
# Entropy diagonal lines (L_entr)                                    1.468425
# Laminarity (LAM)                                                   0.729248
# Trapping time (TT)                                                 3.217641
# Longest vertical line length (V_max)                              14.000000
# Entropy vertical lines (V_entr)                                    1.518579
# Average white vertical line length (W)                            34.581716
# Longest white vertical line length (W_max)                       270.000000
# Longest white vertical line length inverse (W_div)                 0.003704
# Entropy white vertical lines (W_entr)                              3.417593
# Ratio determinism / recurrence rate (DET/RR)                      12.384984
# Ratio laminarity / determinism (LAM/DET)                           0.932740
#
#                                                     benzene_toluene_Y_joint  \
# Recurrence rate                                                    0.041588
# Determinism                                                        1.000000
# Average diagonal line length (L)                                   2.750000
# Longest diagonal line length (L_max)                               4.000000
# Divergence (DIV)                                                   0.250000
# Entropy diagonal lines (L_entr)                                    1.039721
# Laminarity (LAM)                                                   0.454545
# Trapping time (TT)                                                 2.500000
# Longest vertical line length (V_max)                               3.000000
# Entropy vertical lines (V_entr)                                    0.693147
# Average white vertical line length (W)                            16.096774
# Longest white vertical line length (W_max)                        23.000000
# Longest white vertical line length inverse (W_div)                 0.043478
# Entropy white vertical lines (W_entr)                              2.101009
# Ratio determinism / recurrence rate (DET/RR)                      24.045455
# Ratio laminarity / determinism (LAM/DET)                           0.454545
#
#                                                     benzene_toluene_D_cross  \
# Recurrence rate                                                    0.017275
# Determinism                                                        0.364989
# Average diagonal line length (L)                                   2.553473
# Longest diagonal line length (L_max)                              16.000000
# Divergence (DIV)                                                   0.062500
# Entropy diagonal lines (L_entr)                                    1.001898
# Laminarity (LAM)                                                   0.419260
# Trapping time (TT)                                                 2.668852
# Longest vertical line length (V_max)                              17.000000
# Entropy vertical lines (V_entr)                                    1.082059
# Average white vertical line length (W)                            90.688966
# Longest white vertical line length (W_max)                      8202.000000
# Longest white vertical line length inverse (W_div)                 0.000122
# Entropy white vertical lines (W_entr)                              4.496903
# Ratio determinism / recurrence rate (DET/RR)                      21.128604
# Ratio laminarity / determinism (LAM/DET)                           1.148690
#
#                                                     ...  \
# Recurrence rate                                     ...
# Determinism                                         ...
# Average diagonal line length (L)                    ...
# Longest diagonal line length (L_max)                ...
# Divergence (DIV)                                    ...
# Entropy diagonal lines (L_entr)                     ...
# Laminarity (LAM)                                    ...
# Trapping time (TT)                                  ...
# Longest vertical line length (V_max)                ...
# Entropy vertical lines (V_entr)                     ...
# Average white vertical line length (W)              ...
# Longest white vertical line length (W_max)          ...
# Longest white vertical line length inverse (W_div)  ...
# Entropy white vertical lines (W_entr)               ...
# Ratio determinism / recurrence rate (DET/RR)        ...
# Ratio laminarity / determinism (LAM/DET)            ...
#
#                                                     benzene_Y_2010-2020_recurrence  \
# Recurrence rate                                                           1.000000
# Determinism                                                               0.972222
# Average diagonal line length (L)                                          5.000000
# Longest diagonal line length (L_max)                                      8.000000
# Divergence (DIV)                                                          0.125000
# Entropy diagonal lines (L_entr)                                           1.945910
# Laminarity (LAM)                                                          1.000000
# Trapping time (TT)                                                        9.000000
# Longest vertical line length (V_max)                                      9.000000
# Entropy vertical lines (V_entr)                                           0.000000
# Average white vertical line length (W)                                         NaN
# Longest white vertical line length (W_max)                                0.000000
# Longest white vertical line length inverse (W_div)                             inf
# Entropy white vertical lines (W_entr)                                     0.000000
# Ratio determinism / recurrence rate (DET/RR)                              0.972222
# Ratio laminarity / determinism (LAM/DET)                                  1.028571
#
#                                                     toluene_D_2010-2020_recurrence  \
# Recurrence rate                                                           0.029998
# Determinism                                                               0.159637
# Average diagonal line length (L)                                          2.408258
# Longest diagonal line length (L_max)                                      9.000000
# Divergence (DIV)                                                          0.111111
# Entropy diagonal lines (L_entr)                                           0.847532
# Laminarity (LAM)                                                          0.273895
# Trapping time (TT)                                                        2.264723
# Longest vertical line length (V_max)                                     11.000000
# Entropy vertical lines (V_entr)                                           0.619145
# Average white vertical line length (W)                                   41.163410
# Longest white vertical line length (W_max)                             3651.000000
# Longest white vertical line length inverse (W_div)                        0.000274
# Entropy white vertical lines (W_entr)                                     4.260117
# Ratio determinism / recurrence rate (DET/RR)                              5.321576
# Ratio laminarity / determinism (LAM/DET)                                  1.715740
#
#                                                     toluene_M_2010-2020_recurrence  \
# Recurrence rate                                                           0.112351
# Determinism                                                               0.392422
# Average diagonal line length (L)                                          2.612613
# Longest diagonal line length (L_max)                                      6.000000
# Divergence (DIV)                                                          0.166667
# Entropy diagonal lines (L_entr)                                           1.033075
# Laminarity (LAM)                                                          0.590195
# Trapping time (TT)                                                        2.925234
# Longest vertical line length (V_max)                                      8.000000
# Entropy vertical lines (V_entr)                                           1.263608
# Average white vertical line length (W)                                   15.438442
# Longest white vertical line length (W_max)                              119.000000
# Longest white vertical line length inverse (W_div)                        0.008403
# Entropy white vertical lines (W_entr)                                     3.167069
# Ratio determinism / recurrence rate (DET/RR)                              3.492829
# Ratio laminarity / determinism (LAM/DET)                                  1.503979
#
#                                                     toluene_Y_2010-2020_recurrence  \
# Recurrence rate                                                           0.259259
# Determinism                                                               0.666667
# Average diagonal line length (L)                                          4.000000
# Longest diagonal line length (L_max)                                      4.000000
# Divergence (DIV)                                                          0.250000
# Entropy diagonal lines (L_entr)                                           0.000000
# Laminarity (LAM)                                                          0.904762
# Trapping time (TT)                                                        2.714286
# Longest vertical line length (V_max)                                      4.000000
# Entropy vertical lines (V_entr)                                           1.004242
# Average white vertical line length (W)                                    5.000000
# Longest white vertical line length (W_max)                                8.000000
# Longest white vertical line length inverse (W_div)                        0.125000
# Entropy white vertical lines (W_entr)                                     1.594167
# Ratio determinism / recurrence rate (DET/RR)                              2.571429
# Ratio laminarity / determinism (LAM/DET)                                  1.357143
#
#                                                     benzene_toluene_D_2010-2020_joint  \
# Recurrence rate                                                              0.074174
# Determinism                                                                  0.585730
# Average diagonal line length (L)                                             2.577878
# Longest diagonal line length (L_max)                                        17.000000
# Divergence (DIV)                                                             0.058824
# Entropy diagonal lines (L_entr)                                              1.035596
# Laminarity (LAM)                                                             0.480908
# Trapping time (TT)                                                           2.593133
# Longest vertical line length (V_max)                                        19.000000
# Entropy vertical lines (V_entr)                                              1.042368
# Average white vertical line length (W)                                      19.918644
# Longest white vertical line length (W_max)                                3652.000000
# Longest white vertical line length inverse (W_div)                           0.000274
# Entropy white vertical lines (W_entr)                                        3.452233
# Ratio determinism / recurrence rate (DET/RR)                                 7.896731
# Ratio laminarity / determinism (LAM/DET)                                     0.821041
#
#                                                     benzene_toluene_M_2010-2020_joint  \
# Recurrence rate                                                              0.238750
# Determinism                                                                  0.838278
# Average diagonal line length (L)                                             3.275000
# Longest diagonal line length (L_max)                                        11.000000
# Divergence (DIV)                                                             0.090909
# Entropy diagonal lines (L_entr)                                              1.550059
# Laminarity (LAM)                                                             0.802211
# Trapping time (TT)                                                           3.434620
# Longest vertical line length (V_max)                                        14.000000
# Entropy vertical lines (V_entr)                                              1.638172
# Average white vertical line length (W)                                       9.589954
# Longest white vertical line length (W_max)                                 120.000000
# Longest white vertical line length inverse (W_div)                           0.008333
# Entropy white vertical lines (W_entr)                                        2.781172
# Ratio determinism / recurrence rate (DET/RR)                                 3.511112
# Ratio laminarity / determinism (LAM/DET)                                     0.956974
#
#                                                     benzene_toluene_Y_2010-2020_joint  \
# Recurrence rate                                                              0.200000
# Determinism                                                                  0.900000
# Average diagonal line length (L)                                             3.000000
# Longest diagonal line length (L_max)                                         4.000000
# Divergence (DIV)                                                             0.250000
# Entropy diagonal lines (L_entr)                                              1.098612
# Laminarity (LAM)                                                             0.500000
# Trapping time (TT)                                                           2.500000
# Longest vertical line length (V_max)                                         3.000000
# Entropy vertical lines (V_entr)                                              0.693147
# Average white vertical line length (W)                                       4.800000
# Longest white vertical line length (W_max)                                  10.000000
# Longest white vertical line length inverse (W_div)                           0.100000
# Entropy white vertical lines (W_entr)                                        1.767009
# Ratio determinism / recurrence rate (DET/RR)                                 4.500000
# Ratio laminarity / determinism (LAM/DET)                                     0.555556
#
#                                                     benzene_toluene_D_2010-2020_cross  \
# Recurrence rate                                                              0.035390
# Determinism                                                                  0.480606
# Average diagonal line length (L)                                             2.714749
# Longest diagonal line length (L_max)                                        14.000000
# Divergence (DIV)                                                             0.071429
# Entropy diagonal lines (L_entr)                                              1.157154
# Laminarity (LAM)                                                             0.525559
# Trapping time (TT)                                                           2.870234
# Longest vertical line length (V_max)                                        17.000000
# Entropy vertical lines (V_entr)                                              1.253209
# Average white vertical line length (W)                                      51.501079
# Longest white vertical line length (W_max)                                3651.000000
# Longest white vertical line length inverse (W_div)                           0.000274
# Entropy white vertical lines (W_entr)                                        4.256965
# Ratio determinism / recurrence rate (DET/RR)                                13.580382
# Ratio laminarity / determinism (LAM/DET)                                     1.093535
#
#                                                     benzene_toluene_M_2010-2020_cross  \
# Recurrence rate                                                              0.006863
# Determinism                                                                  0.071429
# Average diagonal line length (L)                                             2.333333
# Longest diagonal line length (L_max)                                         3.000000
# Divergence (DIV)                                                             0.333333
# Entropy diagonal lines (L_entr)                                              0.636514
# Laminarity (LAM)                                                             0.142857
# Trapping time (TT)                                                           3.500000
# Longest vertical line length (V_max)                                         5.000000
# Entropy vertical lines (V_entr)                                              0.562335
# Average white vertical line length (W)                                      75.335106
# Longest white vertical line length (W_max)                                 119.000000
# Longest white vertical line length inverse (W_div)                           0.008403
# Entropy white vertical lines (W_entr)                                        1.714695
# Ratio determinism / recurrence rate (DET/RR)                                10.408163
# Ratio laminarity / determinism (LAM/DET)                                     2.000000
#
#                                                     benzene_toluene_Y_2010-2020_cross
# Recurrence rate                                                              0.000000
# Determinism                                                                       NaN
# Average diagonal line length (L)                                                  NaN
# Longest diagonal line length (L_max)                                         0.000000
# Divergence (DIV)                                                                  inf
# Entropy diagonal lines (L_entr)                                              0.000000
# Laminarity (LAM)                                                                  NaN
# Trapping time (TT)                                                                NaN
# Longest vertical line length (V_max)                                         0.000000
# Entropy vertical lines (V_entr)                                              0.000000
# Average white vertical line length (W)                                       9.000000
# Longest white vertical line length (W_max)                                   9.000000
# Longest white vertical line length inverse (W_div)                           0.111111
# Entropy white vertical lines (W_entr)                                        0.000000
# Ratio determinism / recurrence rate (DET/RR)                                      NaN
# Ratio laminarity / determinism (LAM/DET)                                          NaN
#
# [16 rows x 36 columns]

# %%
from RQA import *
plots = [['benzene','D','recurrence','plot'],
        ['benzene','M','recurrence','plot'],
        ['benzene','Y','recurrence','plot'],
        ['toluene','D','recurrence','plot'],
        ['toluene','M','recurrence','plot'],
        ['toluene','Y','recurrence','plot'],
        [['benzene','toluene'],'D','joint','plot'],
        [['benzene','toluene'],'M','joint','plot'],
        [['benzene','toluene'],'Y','joint','plot'],
        [['benzene','toluene'],'D','cross','plot'],
        [['benzene','toluene'],'M','cross','plot'],
        [['benzene','toluene'],'Y','cross','plot'],
        ['benzene','D','recurrence','plot',['1997','2009']],
        ['benzene','M','recurrence','plot',['1997','2009']],
        ['benzene','Y','recurrence','plot',['1997','2009']],
        ['toluene','D','recurrence','plot',['1997','2009']],
        ['toluene','M','recurrence','plot',['1997','2009']],
        ['toluene','Y','recurrence','data',['1997','2009']],
        [['benzene','toluene'],'D','joint','plot',['1997','2009']],
        [['benzene','toluene'],'M','joint','plot',['1997','2009']],
        [['benzene','toluene'],'Y','joint','plot',['1997','2009']],
        [['benzene','toluene'],'D','cross','plot',['1997','2009']],
        [['benzene','toluene'],'M','cross','plot',['1997','2009']],
        [['benzene','toluene'],'Y','cross','plot',['1997','2009']],
        ['benzene','D','recurrence','plot',['2010','2020']],
        ['benzene','M','recurrence','plot',['2010','2020']],
        ['benzene','Y','recurrence','plot',['2010','2020']],
        ['toluene','D','recurrence','plot',['2010','2020']],
        ['toluene','M','recurrence','plot',['2010','2020']],
        ['toluene','Y','recurrence','plot',['2010','2020']],
        [['benzene','toluene'],'D','joint','plot',['2010','2020']],
        [['benzene','toluene'],'M','joint','plot',['2010','2020']],
        [['benzene','toluene'],'Y','joint','plot',['2010','2020']],
        [['benzene','toluene'],'D','cross','plot',['2010','2020']],
        [['benzene','toluene'],'M','cross','plot',['2010','2020']],
        [['benzene','toluene'],'Y','cross','plot',['2010','2020']]

]

for p in plots:
    rqa(*p)
# Out:
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_D_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_M_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_Y_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_D_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_M_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_Y_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_D_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_M_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_Y_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_D_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_M_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_Y_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_D_1997-2009_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_M_1997-2009_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_Y_1997-2009_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_D_1997-2009_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_M_1997-2009_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_D_1997-2009_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_M_1997-2009_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_Y_1997-2009_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_D_1997-2009_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_M_1997-2009_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_Y_1997-2009_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_D_2010-2020_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_M_2010-2020_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_Y_2010-2020_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_D_2010-2020_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_M_2010-2020_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# toluene_Y_2010-2020_recurrence
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_D_2010-2020_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_M_2010-2020_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_Y_2010-2020_joint
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_D_2010-2020_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_M_2010-2020_cross
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority
#
#
# benzene_toluene_Y_2010-2020_cross

# %%
from RQA import *
a,b = rqa('benzene','D','recurrence','data',['1997','2009'])
# Out:
# [Platform 'Apple']
# Vendor: Apple
# Version: OpenCL 1.2 (Aug 30 2021 03:51:40)
# Profile: FULL_PROFILE
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event
#
#
# [Device 'Intel(R) Core(TM) m3-7Y32 CPU @ 1.10GHz']
# Vendor: Intel
# Type: 2
# Version: OpenCL 1.2
# Profile: FULL_PROFILE
# Max Clock Frequency: 1200
# Global Mem Size: 8589934592
# Address Bits: 64
# Max Compute Units: 4
# Max Work Group Size: 1024
# Max Work Item Dimensions: 3
# Max Work Item Sizes: [1024, 1, 1]
# Local Mem Size: 32768
# Max Mem Alloc Size: 2147483648
# Extensions: cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_fp64 cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics cl_khr_local_int32_base_atomics cl_khr_local_int32_extended_atomics cl_khr_byte_addressable_store cl_khr_int64_base_atomics cl_khr_int64_extended_atomics cl_khr_3d_image_writes cl_khr_image2d_from_buffer cl_APPLE_fp64_basic_ops cl_APPLE_fixed_alpha_channel_orders cl_APPLE_biased_fixed_point_image_formats cl_APPLE_command_queue_priority

# %%
a
# Out:
# 'benzene_D_1997-2009_recurrence'

# %%
r = [['benzene','toluene'],'Y','cross','data',['2010','2020']]
a,b = rqa(r[0],)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('naei_ukdata_20230203142606.csv')
YEARS = ['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', 
        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', 
        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', 
        '2017', '2018', '2019', '2020']

# %%
years = np.arange(5,35)
df.iloc[:, 6]
# Out:
# 0      54.557041
# 1       0.002656
# 2       0.000052
# 3       0.000055
# 4       0.003757
#          ...
# 221     0.000013
# 222     0.000233
# 223     0.008969
# 224     0.651683
# 225     0.496468
# Name: 1991, Length: 226, dtype: float64

# %%
for y in years:
    try:
        df.iloc[:,y]=pd.to_numeric(df.iloc[:,y], errors='coerce')
    except:
        pass

# %%
for index,row in df.iterrows():
    to_plot = row.iloc[5:35]
    to_plot.plot(kind='line',x=to_plot.index,y=to_plot)

# %%
df
# Out:
#          Gas NFR/CRF Group                                          Source  \
# 0    Benzene            1A                                             NaN
# 1    Benzene          1A1a  Miscellaneous industrial/commercial combustion
# 2    Benzene          1A1a                                  Power stations
# 3    Benzene          1A1a                                  Power stations
# 4    Benzene          1A1a                                  Power stations
# ..       ...           ...                                             ...
# 221  Benzene   z_1A3ai(ii)      Aircraft between UK and Gibraltar - Cruise
# 222  Benzene  z_1A3aii(ii)                      Aircraft - domestic cruise
# 223  Benzene  z_1A3aii(ii)                      Aircraft - domestic cruise
# 224  Benzene    z_1A3di(i)        Shipping - international IPCC definition
# 225  Benzene    z_1A3di(i)        Shipping - international IPCC definition
#
# ...

# %%
df.sort_values(by=YEARS,ascending=False)
# Out:
#          Gas NFR/CRF Group                                      Source  \
# 0    Benzene            1A                                         NaN
# 76   Benzene         1A3bi       Road transport - cars - urban driving
# 80   Benzene         1A3bi          Road transport - cars - cold start
# 74   Benzene         1A3bi       Road transport - cars - rural driving
# 163  Benzene            1B                                         NaN
# ..       ...           ...                                         ...
# 134  Benzene         1A4ai            Railways - stationary combustion
# 147  Benzene         1A4bi                         Domestic combustion
# 154  Benzene         1A4ci         Agriculture - stationary combustion
# 221  Benzene   z_1A3ai(ii)  Aircraft between UK and Gibraltar - Cruise
# 71   Benzene      1A3ai(i)     Aircraft between UK and Gibraltar - TOL
#
#             Activity      Units       1990          1991       1992  \
# ...

# %%
df.columns
# Out:
# Index(['Gas', 'NFR/CRF Group', 'Source', 'Activity', 'Units', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020'],
#       dtype='object')

# %%
df = df.sort_values('Source')
uniqies = df['Source'].unique()

# %%
df['Source']=df['Source'].fillna('Other')

# %%
combined=pd.DataFrame(columns=['Gas', 'NFR/CRF Group', 'Source', 'Activity', 'Units', '1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019', '2020'])

# %% [markdown]
# Agriculture, Aircraft, Autogenerators, Blast furnaces, Cement, Chemical industry, Chemicals, Coal tar, Coke production, Collieries, Domestic combustion, Fishing vessels, Food & drink, Gas Terminal, Gas leakage, Gas production, Gas terminal, Gasification processes, Heat supply, House and garden machinery, Incineration, Industrial off-road mobile machinery, Inland goods-carrying vessels, Iron and steel, Landfill, Lime production, Methanol production, Miscellaneous industrial/commercial combustion, Motorboats / workboats, Non-Ferrous Metal (combustion), Nuclear fuel production, Oil Terminal, Other industrial combustion, Personal watercraft, Petrol stations, Petrol terminals, Petroleum processes, Public sector combustion, Pulp, Paper and Print (combustion), Rail, Refineries, Road transport - HGV, Road transport - LGVs, Road transport - buses and coaches, Road transport - cars, Road transport - general, Road transport - mo, Sailing boats, Sea going vessel, Shipping, Sinter production, Solid smokeless fuel production, Solvent and oil recovery, Town gas manufacture, Upstream Gas Production, Upstream Oil Production

# %%
a = df[df['Source'].str.contains("Upstream Oil Production")]

# %%
b = a.sum(axis=0)
b = b.to_frame().T

# %%
combined = pd.concat([combined,b])

# %%
combined
# Out:
#                      Gas  NFR/CRF Group  \
# 0  BenzeneBenzeneBenzene  1A1c1B2ai1B2c
#
#                                               Source  \
# 0  Upstream Oil Production - fuel combustionUpstr...
#
#                                             Activity  \
# 0  Natural gasNon-fuel combustionNon-fuel combustion
#
#                          Units      1990     1991      1992      1993  \
# 0  kilotonnekilotonnekilotonne  0.170244  0.16444  0.171064  0.180629
#
#        1994  ...      2011      2012      2013      2014      2015     2016  \
# 0  0.216948  ...  0.191198  0.154117  0.128266  0.125565  0.111451  0.11917
#
#        2017      2018      2019                              2020
# 0  0.159362  0.188861  0.166616  0.0109063010.0094332310.09357592
#
# [1 rows x 36 columns]

# %%
for index,row in combined.iterrows():
    to_plot = row.iloc[5:35]
    to_plot.plot(kind='line',x=to_plot.index,y=to_plot)

# %%
cats = ['Agriculture', 'Aircraft', 'Autogenerators', 'Blast furnaces', 'Cement', 'Chemical industry', 'Chemicals', 
        'Coal tar', 'Coke production', 'Collieries', 'Domestic combustion', 'Fishing vessels', 'Food & drink', 
        'Gas Terminal', 'Gas leakage', 'Gas production', 'Gas terminal', 'Gasification processes', 'Heat supply', 
        'House and garden machinery', 'Incineration', 'Industrial off-road mobile machinery', 
        'Inland goods-carrying vessels', 'Iron and steel', 'Landfill', 'Lime production', 'Methanol production', 
        'Miscellaneous industrial/commercial combustion', 'Motorboats / workboats', 'Non-Ferrous Metal (combustion)', 
        'Nuclear fuel production', 'Oil Terminal', 'Other industrial combustion', 'Personal watercraft', 'Petrol stations', 
        'Petrol terminals', 'Petroleum processes', 'Public sector combustion', 'Pulp, Paper and Print (combustion)', 
        'Rail', 'Refineries', 'Road transport - HGV', 'Road transport - LGVs', 'Road transport - buses and coaches', 
        'Road transport - cars', 'Road transport - general', 'Road transport - mo', 'Sailing boats', 'Sea going vessel', 
        'Shipping', 'Sinter production', 'Solid smokeless fuel production', 'Solvent and oil recovery', 
        'Town gas manufacture', 'Upstream Gas Production', 'Upstream Oil Production']

# %%
combined2 = pd.DataFrame(columns=['Gas', 'NFR/CRF Group', 'Source', 'Activity', 'Units', '1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019', '2020'])
for i in cats:
       a = df[df['Source'].str.contains(i)]
       b = a.sum(axis=0)
       b = b.to_frame().T
       b['Group'] = i 
       combined2 = pd.concat([combined2,b])
# Out:
# /Users/brontekellett/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
for index,row in combined2.iterrows():
    to_plot = row.iloc[5:35]
    ax = to_plot.plot(kind='line',x=to_plot.index,y=to_plot, label=row.iloc[-1])
ax.legend(bbox_to_anchor=(1, 1))

# %%
combined2 = combined2.sort_values(['1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019', '2020'],ascending=False)

# %%
top_10=combined2.iloc[0:10,:]
fig, ax = plt.subplots()
for index,row in top_10.iterrows():
    to_plot = row.iloc[5:35]
    ax = to_plot.plot(kind='line',x=to_plot.index,y=to_plot, label=row.iloc[-1])
ax.legend(bbox_to_anchor=(1, 1))

# %%
first = combined2[['Gas', 'NFR/CRF Group', 'Source', 'Activity', 'Units','1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009','Group']]
first = first.sort_values(['1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009'], ascending=False)
first_10=first.iloc[0:10,:]
fig, ax = plt.subplots()
for index,row in first_10.iterrows():
    to_plot = row.iloc[5:17]
    ax = to_plot.plot(kind='line',x=to_plot.index,y=to_plot, label=row.iloc[-1])
ax.legend(bbox_to_anchor=(1, 1))

# %%
second = combined2[['Gas', 'NFR/CRF Group', 'Source', 'Activity', 'Units', '2010', '2011', 
        '2012', '2013', '2014', '2015', '2016', '2017', '2018','2019', '2020', 'Group']]
second = second.sort_values(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019', '2020'],ascending=False)
second_10=second.iloc[0:10,:]
fig, ax = plt.subplots()
for index,row in second_10.iterrows():
    to_plot = row.iloc[6:-2]
    ax = to_plot.plot(kind='line',x=to_plot.index,y=to_plot, label=row.iloc[-1])
ax.legend(bbox_to_anchor=(1, 1))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
sum = combined2.sum(axis=0)
sum = sum.drop(labels=['Group']) 
sum
# Out:
# 1990    61.9059
# 1991    62.4739
# 1992    60.8757
# 1993    58.2591
# 1994    55.3325
# 1995    52.2123
# 1996    50.6148
# 1997     46.624
# 1998    42.9034
# 1999    39.3233
# 2000    23.7238
# 2001    23.1959
# 2002    21.7686
# 2003    21.1535
# 2004    20.6223
# 2005    19.4136
# 2006    18.5659
# 2007    17.5209
# 2008    16.2753
# 2009     13.376
# 2010    12.8996
# 2011    11.8405
# 2012     11.365
# 2013    11.0835
# 2014    10.4671
# 2015    10.4806
# 2016    10.1114
# 2017    10.3717
# 2018     10.639
# 2019    10.1301
# dtype: object

# %%
ax = sum.plot(kind='line', x = sum.index, y = sum)

# %%
sum.columns
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')
